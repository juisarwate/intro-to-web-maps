# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('ukr_border_crossings_140422.xlsx')
df.head()
# Out:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  Poland: https://www.gov.pl/web/mswia-en/inform...         NaN         NaN
# 1                Moldova: https://dpsu.gov.ua/en/map         NaN         NaN
# 2  Hungary: https://dpsu.gov.ua/en/Where-and-how-...         NaN         NaN
# 3  Slovakia: https://dpsu.gov.ua/en/Where-and-how...         NaN         NaN
# 4  Belarus: https://kordon.customs.gov.ua/en/home...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4 Unnamed: 5                              Unnamed: 6  \
# 0         NaN         NaN        NaN  Matches multiple humanitarian partners
# 1         NaN         NaN        NaN  Matches multiple humanitarian partners
# 2         NaN         NaN        NaN  Matches multiple humanitarian partners
# 3         NaN         NaN        NaN  Matches multiple humanitarian partners
# 4         NaN         NaN        NaN  Matches multiple humanitarian partners
#
#    crossing count
# 0             8.0
# ...

# %%
df.fillna(0, inplace=True)
df.head()
# Out:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  Poland: https://www.gov.pl/web/mswia-en/inform...         0.0         0.0
# 1                Moldova: https://dpsu.gov.ua/en/map         0.0         0.0
# 2  Hungary: https://dpsu.gov.ua/en/Where-and-how-...         0.0         0.0
# 3  Slovakia: https://dpsu.gov.ua/en/Where-and-how...         0.0         0.0
# 4  Belarus: https://kordon.customs.gov.ua/en/home...         0.0         0.0
#
#    Unnamed: 3  Unnamed: 4 Unnamed: 5                              Unnamed: 6  \
# 0         0.0         0.0          0  Matches multiple humanitarian partners
# 1         0.0         0.0          0  Matches multiple humanitarian partners
# 2         0.0         0.0          0  Matches multiple humanitarian partners
# 3         0.0         0.0          0  Matches multiple humanitarian partners
# 4         0.0         0.0          0  Matches multiple humanitarian partners
#
#    crossing count
# 0             8.0
# ...

# %%
import geopandas as gpd

filename = 'ukr_border_crossings.shp'
file = open('ukr_border_crossings.shp')
ukraine = gpd.read_file('ukr_border_crossings.shp')
ukraine.head()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open ukr_border_crossings.shx or ukr_border_crossings.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /var/folders/4r/qbtxk1s968n5kqwsz68bgc4c0000gn/T/ipykernel_15455/1064465605.py in <module>
#       3 filename = 'ukr_border_crossings.shp'
#       4 file = open('ukr_border_crossings.shp')
# ----> 5 ukraine = gpd.read_file('ukr_border_crossings.shp')
#       6 ukraine.head()
#
# /usr/local/lib/python3.9/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     199
# ...
